# %% [markdown]
# <a href="https://colab.research.google.com/github/Natkitta252603/bsc_dpdm24/blob/main/Chapter2_Understanding_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Import data from different formats

# %% [markdown]
# ##CSV

# %%
# prompt: mount gdrive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# expected problem : Encoding Error
# solution chooses

# %%
# prompt: read csv flie with pandas

import pandas as pd
file_path = '/content/drive/MyDrive/bsc_spdm4/tis_name_02122567.csv'
df = pd.read_csv(file_path,encoding='cp874')
df
# Out:
#       ลำดับ            เลขที่ มอก.  \
# 0         1                 2-2525
# 1         2                 3-2562
# 2         3          4 เล่ม 1-2558
# 3         4          4 เล่ม 2-2552
# 4         5          4 เล่ม 3-2563
# ...     ...                    ...
# 5241   5242      63283 เล่ม 2-2566
# 5242   5243      63283 เล่ม 3-2566
# 5243   5244             63294-2566
# 5244   5245             63325-2566
# 5245   5246  80601 เล่ม 2(69)-2564
#
#                                       ชื่อ มอก. ภาษาไทย  \
# 0                 ขวดแก้วสำหรับเครื่องดื่มประเภทอัดก๊าซ
# 1                                                น้ำปลา
# 2     หลอดไฟฟ้าไส้ทังสเตนสำหรับใช้ในที่อยู่อาศัยและท...
# 3     วิธีมาตรฐานในการวัดอุณหภูมิที่เพิ่มขึ้นของขั้ว...
# 4     หลอดไฟฟ้าไส้ทังสเตนสำหรับใช้ในที่อยู่อาศัยและท...
# ...                                                 ...
# 5241  การวัด การควบคุม และระบบอัตโนมัติในกระบวนการอุ...
# 5242  การวัด การควบคุม และระบบอัตโนมัติในกระบวนการอุ...
# ...

# %% [markdown]
# ##Excel
# expected

# %%
# prompt: open excel file for the sheet name X

from google.colab import drive
import pandas as pd

drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/bsc_spdm4/export62_64.xlsx' # Replace with your file path
sheet_name = 'X' # Replace with your sheet name

try:
  df_excel = pd.read_excel(excel_file_path, sheet_name=sheet_name)
  df_excel.head()
  print(df)
except FileNotFoundError:
  print(f"Error: File not found at {file_path}")
except ValueError:
  print(f"Error: Sheet '{sheet_name}' not found in the Excel file.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# An unexpected error occurred: name 'excel_file_path' is not defined

# %%
file_path = '/content/drive/MyDrive/bsc_spdm4/export62_64.xlsx' # Replace with your file path
df_excel = pd.read_excel(file_path, sheet_name="Export 64")
df_excel.head()
# Out:
#    Unnamed: 0 Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0         NaN  Export 64          NaN                  NaN        NaN
# 1         NaN   ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 2         NaN       2564            1             01012100        000
# 3         NaN       2564            1             01012900        000
# 4         NaN       2564            1             01022100        001
#
#           Unnamed: 5      Unnamed: 6                  Unnamed: 7  \
# 0                NaN             NaN                         NaN
# 1  หน่วยตามรหัสสถิติ     คำอธิบายไทย                    คำอธิบาย
# 2                C62  สำหรับทำพันธุ์  Pure-bred breeding animals
# 3                C62          อื่น ๆ                       Other
# 4                C62        โคตัวผู้                 Bullocks
#
#             Unnamed: 8           Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0                  NaN                  NaN          NaN          NaN
# ...

# %%
# prompt: open sheet number 3 of the excel file and select only the table part

from google.colab import drive
import pandas as pd

drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/bsc_spdm4/export62_64.xlsx' # Replace with your file path

try:
  # Read sheet number 3 (index 2)
  df_excel = pd.read_excel(file_path, sheet_name=2)

  # Assuming the table starts from the first row with data
  # Identify the last row containing data (excluding empty rows at the end)
  last_row = 0
  for i in range(len(df_excel)):
      if not df_excel.iloc[i].isnull().all(): # Check for entirely empty row
          last_row = i
  df_excel = df_excel.iloc[:last_row+1] # Select the portion of the DataFrame

  print(df_excel)
except FileNotFoundError:
  print(f"Error: File not found at {file_path}")
except ValueError:
  print(f"Error: Sheet 3 not found in the Excel file.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#       Unnamed: 0 Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0            NaN  Export 64          NaN                  NaN        NaN
# 1            NaN   ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 2            NaN       2564            1             01012100        000
# 3            NaN       2564            1             01012900        000
# 4            NaN       2564            1             01022100        001
# ...          ...        ...          ...                  ...        ...
# 1375         NaN       2564            1             25309090        005
# 1376         NaN       2564            1             25309090        090
# 1377         NaN       2564            1             26011110        000
# 1378         NaN       2564            1             26011190        000
# ...

# %%
excel_file_path = '/content/drive/MyDrive/bsc_spdm4/export62_64.xlsx'
df_excel = pd.read_excel(excel_file_path, sheet_name=2)
df_excel.head()
# Out:
#    Unnamed: 0 Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0         NaN  Export 64          NaN                  NaN        NaN
# 1         NaN   ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 2         NaN       2564            1             01012100        000
# 3         NaN       2564            1             01012900        000
# 4         NaN       2564            1             01022100        001
#
#           Unnamed: 5      Unnamed: 6                  Unnamed: 7  \
# 0                NaN             NaN                         NaN
# 1  หน่วยตามรหัสสถิติ     คำอธิบายไทย                    คำอธิบาย
# 2                C62  สำหรับทำพันธุ์  Pure-bred breeding animals
# 3                C62          อื่น ๆ                       Other
# 4                C62        โคตัวผู้                 Bullocks
#
#             Unnamed: 8           Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0                  NaN                  NaN          NaN          NaN
# ...

# %%
excel_file_path = '/content/drive/MyDrive/bsc_spdm4/export62_64.xlsx'
df_excel = pd.read_excel(excel_file_path, sheet_name="Export 64",skiprows=2,usecols=(1,2,3,4))
df_excel.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 0      2564            1              1012100          0
# 1      2564            1              1012900          0
# 2      2564            1              1022100          1
# 3      2564            1              1022919          0
# 4      2564            1              1023100          0

# %%
excel_file_path = '/content/drive/MyDrive/bsc_spdm4/export62_64.xlsx'
df_excel = pd.read_excel(excel_file_path, sheet_name="Export 64",skiprows=2,usecols=range (1,10))
df_excel.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0      2564            1              1012100          0               C62
# 1      2564            1              1012900          0               C62
# 2      2564            1              1022100          1               C62
# 3      2564            1              1022919          0               C62
# 4      2564            1              1023100          0               C62
#
#       คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 0  สำหรับทำพันธุ์  Pure-bred breeding animals                   44
# 1          อื่น ๆ                       Other                   35
# 2        โคตัวผู้                 Bullocks                    9674
# 3          อื่น ๆ                       Other                10976
# 4  สำหรับทำพันธุ์  Pure-bred breeding animals                 3169
#
#    มูลค่าส่งออกเงินบาท
# 0               196720
# 1               182000
# 2            145263681
# ...

# %%
df_excel.tail()
# Out:
#       ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 1373      2564            1             25309090          5               KGM
# 1374      2564            1             25309090         90               KGM
# 1375      2564            1             26011110          0               KGM
# 1376      2564            1             26011190          0               KGM
# 1377      2564            1             26011290          0               KGM
#
#                คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 1373        แร่ไพโรฟิลไรท์                 Pyrophylite               272000
# 1374                อื่น ๆ                       Other              2109246
# 1375  แร่เฮมาไทต์และหัวแร่  Haematite and concentrates             42930945
# 1376                อื่น ๆ                       Other                    5
# 1377                อื่น ๆ                       Other                   70
#
#       มูลค่าส่งออกเงินบาท
# ...

# %% [markdown]
# ##Google Sheets

# %%
# prompt: open google sheets

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

spreadsheet_key = '1rKtk5iXryXs8pXXp9NF1C09FkL0Q9G587Qrg45H6Sls/edit?gid=1399181054#gid=1399181054'

# Open the Google Sheet by name
try:
    sh = gc.open('Your Spreadsheet Name') # Replace with your spreadsheet name
    print("Spreadsheet opened successfully.")

    # Or open by URL
    # sh = gc.open_by_url('your_spreadsheet_url')

    # Select a specific worksheet
    worksheet = sh.sheet1  # or sh.worksheet('Sheet1') for a specific sheet name
    print(f"Worksheet '{worksheet.title}' selected.")

except gspread.SpreadsheetNotFound:
    print("Spreadsheet not found. Please check the name or URL.")
except gspread.exceptions.APIError as e:
  print(f"An error occurred while accessing the Google Sheet: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Spreadsheet not found. Please check the name or URL.

# %% [markdown]
# ##JSON

# %%
# prompt: load JSON file name data_station from the drive

import json
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/data_station.json' # Replace with the actual file path

try:
  with open(file_path, 'r') as f:
    data = json.load(f)
    df_json = pd.DataFrame(data)
    print(df_json)
except FileNotFoundError:
  print(f"Error: File not found at {file_path}")
except json.JSONDecodeError:
  print(f"Error: Invalid JSON format in the file at {file_path}")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: File not found at /content/drive/MyDrive/data_station.json

# %%
import pandas as pd
json_file_path = '/content/drive/MyDrive/bsc_spdm4/memo_2298.json'
df_json = pd.read_json(json_file_path)
df_json.head()
# Out:
#    MemoId       DocumentNo  TemplateId            TemplateName  \
# 0    2298  REQ-2019-002298        1050  แบบฟอร์มเบิกเงินสดย่อย
# 1    2298  REQ-2019-002298        1050  แบบฟอร์มเบิกเงินสดย่อย
#
#                        ToPerson                   CcPerson  CreatorId  \
# 0  Mr. Suwittawat Ragsameorwong  Miss Soravee Ritgarunvong          8
# 1  Mr. Suwittawat Ragsameorwong  Miss Soravee Ritgarunvong          8
#
#                        CNameTh                     CNameEn  CPositionId  ...  \
# 0  นางสาวเพิ่มสิน คุณวิสิฏสิริ  Miss Phoemsin Kunwisitsiri           16  ...
# 1  นางสาวเพิ่มสิน คุณวิสิฏสิริ  Miss Phoemsin Kunwisitsiri           16  ...
#
#   Amount               RequestDate              ModifiedDate PersonWaitingId  \
# 0    300  2019-03-21T08:43:47.490Z  2019-03-22T12:03:23.447Z             NaN
# 1    300  2019-03-21T08:43:47.490Z  2019-03-22T12:03:23.447Z             NaN
#
#               PersonWaiting  CompanyId         CompanyName  CompletedDate  \
# ...

# %%
import pandas as pd
f = open ('/content/drive/MyDrive/bsc_spdm4/memo_2298.json')
json_2298 = json.load(f)
f.close()

# %%
json_2298
# Out:
# {'MemoId': 2298,
#  'DocumentNo': 'REQ-2019-002298',
#  'TemplateId': 1050,
#  'TemplateName': 'แบบฟอร์มเบิกเงินสดย่อย',
#  'ToPerson': 'Mr. Suwittawat Ragsameorwong',
#  'CcPerson': 'Miss Soravee Ritgarunvong',
#  'CreatorId': 8,
#  'CNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'CNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'CPositionId': 16,
#  'CPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'CPositionEn': 'Account Manager',
#  'CDepartmentId': 4,
#  'CDepartmentTh': 'Management',
#  'CDepartmentEn': 'Management',
#  'CDivisionId': None,
#  'CDivisionTh': None,
#  'CDivisionEn': None,
#  'RequesterId': 8,
#  'RNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'RNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'RPositionId': 16,
#  'RPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'RPositionEn': 'Account Manager',
#  'RDepartmentId': 4,
#  'RDepartmentTh': 'Management',
#  'RDepartmentEn': 'Management',
#  'RDivisionId': None,
#  'RDivisionTh': None,
#  'RDivisionEn': None,
#  'MemoSubject': 'เบิกเงินสดย่อย',
# ...

# %%
json_2298['StatusName']
# Out:
# 'Rejected'

# %% [markdown]
# #Quiz3
# print  'ActorName'และ 'ActionProcess' ของ action history แรก

# %%
# prompt: print 'ActorName'และ 'ActionProcess' ของ action history แรก

print(json_2298['ActionHistory'][0]['ActorName'])
print(json_2298['ActionHistory'][0]['ActionProcess'])
# Out:
# นางสาวเพิ่มสิน คุณวิสิฏสิริ
# submit

# %% [markdown]
# ##Distance

# %%
import pandas as pd
data = [[1, 2], [-1, 4], [0, 3], [-3, -2]]
df = pd.DataFrame(data,columns=['X1','X2'])
df
# Out:
#    X1  X2
# 0   1   2
# 1  -1   4
# 2   0   3
# 3  -3  -2

# %%
# prompt: drew scatter plot of the df.drew blod line for X1 and X2 axes

import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with 'X1' and 'X2' columns

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.scatter(df['X1'], df['X2'])
plt.plot([-3,1],[0,0],color='black',linewidth=2)
plt.plot([0,0],[-2,4],color='black',linewidth=2)

plt.xlabel("X1", fontweight='bold')  # Bold X1 axis label
plt.ylabel("X2", fontweight='bold')  # Bold X2 axis label

plt.title("Scatter Plot of X1 vs X2")
plt.grid(True)  # Add a grid for better visualization
plt.show()

# %%
# prompt: do min-max normalization for the df2 for each column separately

import pandas as pd

# Assuming df2 is your DataFrame
# Replace with your actual DataFrame name if different

# Example DataFrame (replace with your actual df2)
data = {'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50], 'C': [100, 200, 300, 400, 500]}
df2 = pd.DataFrame(data)

def min_max_normalize_column(column):
  min_val = column.min()
  max_val = column.max()
  normalized_column = (column - min_val) / (max_val - min_val)
  return normalized_column

# Apply min-max normalization to each column of df2
for column in df2.columns:
    df2[column] = min_max_normalize_column(df2[column])

df2

# %%
distance_matrix = squareform(pdist(df2[['X1','X2']]))
distance_matrix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-a55bbdcbda18> in <cell line: 1>()
# ----> 1 distance_matrix = squareform(pdist(df2[['X1','X2']]))
#       2 distance_matrix
#
# NameError: name 'squareform' is not defined

# %%
# prompt: plot histogram of df2 X1

import matplotlib.pyplot as plt

# Assuming df is already defined and contains a column named 'X1'
plt.figure(figsize=(8, 6))
plt.hist(df['X1'], bins=10)  # Adjust the number of bins as needed
plt.xlabel("X1 Values")
plt.ylabel("Frequency")
plt.title("Histogram of X1")
plt.show()

# %% [markdown]
# #Normalization (Z-score & Min-Max normalization)
